# %% [markdown]
# <a href="https://colab.research.google.com/github/bgsw404notfound/SkiSphe/blob/main/TF_Vectorbased.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
import requests
import os

# Load datasets
associates = pd.read_csv("/content/drive/MyDrive/SkillSphe/associates_with_grouped_skills.csv")
projects = pd.read_csv("/content/drive/MyDrive/SkillSphe/projects_with_grouped_skills.csv")
learning_content = pd.read_csv("/content/drive/MyDrive/SkillSphe/learning_content.csv")
preferences = pd.read_csv("/content/drive/MyDrive/SkillSphe/learning_preferences.csv")

# Convert project_id to string in both DataFrames to ensure consistent matching
associates["project_id"] = associates["project_id"].astype(str)
projects["project_id"] = projects["project_id"].astype(str)

# Define skill levels
skill_levels = {"L1": 1, "L2": 2, "L3": 3, "L4": 4}
inverse_skill_levels = {1: "L1", 2: "L2", 3: "L3", 4: "L4"}

# Identify skill columns
metadata_columns_assoc = ['associate_id', 'name', 'role', 'years_of_experience', 'grade', 'project_id',
                         'certifications_obtained', 'certifications_in_progress', 'available_learning_time',
                         'learning_time_utilized_previous_year', 'skills_recommended_by_manager',
                         'skills_recommended_by_department', 'skills_selected_for_own', 'L1', 'L2', 'L3', 'L4']
skill_columns_assoc = [col for col in associates.columns if col not in metadata_columns_assoc]

metadata_columns_proj = ['project_id', 'project_name', 'Project_status']
skill_columns_proj = [col for col in projects.columns if col not in metadata_columns_proj]

# Precompute TF-IDF vectors for local course titles
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(learning_content["Title"])
print("TF-IDF matrix computed")

# Function to search external MOOC platforms (simulated with a web query)
def search_external_mooc(skill, desired_level):
    # Simulated search (replace with real API in production)
    # Using a hypothetical free course aggregator API or web search as a placeholder
    query = f"{skill} {desired_level} course site:coursera.org OR site:edx.org OR site:udemy.com"
    try:
        # Placeholder for a real API call or web search
        # Example: Google Custom Search API or Class Central API would go here
        # For now, simulate a response
        response = requests.get(f"https://api.classcentral.com/search?q={query}", timeout=5)  # Hypothetical endpoint
        if response.status_code == 200:
            data = response.json()
            if data.get("results"):
                course = data["results"][0]["title"]
                platform = data["results"][0].get("platform", "External Platform")
                return f"{course} (via {platform})"
    except Exception as e:
        print(f"External search failed for {skill}: {e}")

    # Fallback response if no real API is available
    return f"{skill} {desired_level} Course (via External Search)"

# AI-based course recommendation with fallback to external MOOC platforms
def recommend_course_tfidf(skill, desired_level, delivery_mode=None):
    # Try local dataset first
    skill_vector = tfidf_vectorizer.transform([skill])
    similarities = cosine_similarity(skill_vector, tfidf_matrix).flatten()

    candidates = learning_content.copy()
    candidates["similarity"] = similarities
    candidates = candidates[candidates["Level"] == desired_level]
    if delivery_mode:
        candidates = candidates[candidates["Format"] == delivery_mode]

    candidates = candidates.sort_values(by="similarity", ascending=False)
    if not candidates.empty:
        return candidates.iloc[0]["Title"]

    # Fallback to external MOOC search
    return search_external_mooc(skill, desired_level)

# Convert skill levels to integers
def level_to_int(value):
    if isinstance(value, str) and value.startswith('L'):
        try:
            return int(value[1:])
        except:
            return 0
    try:
        return int(value)
    except:
        return 0

# Parse recommended skills
def parse_recommended_skills(skills_str):
    skills_dict = {}
    if pd.isna(skills_str):
        return skills_dict
    for item in skills_str.split(','):
        item = item.strip()
        if '-' in item:
            parts = item.split('-')
            if len(parts) == 2:
                skill = parts[0].strip()
                level = level_to_int(parts[1].strip())
                if skill:
                    skills_dict[skill] = max(level, skills_dict.get(skill, 0))
    return skills_dict

# Cluster associates based on skill profiles
skill_matrix = associates[skill_columns_assoc].applymap(level_to_int).fillna(0)
kmeans = KMeans(n_clusters=min(5, len(associates)), random_state=42)
associates["cluster"] = kmeans.fit_predict(skill_matrix)
print("Associates clustered based on skill profiles")

# Combined function with AI-based collaborative recommendations
def create_learning_path_and_trainings(row):
    associate_id = row["associate_id"]
    cluster = row["cluster"]
    project_recommendations = []
    project_skill_gaps = []
    training_recommendations = []
    training_skill_gaps = []
    current_levels = []
    recommended_levels = []
    current_project_levels = []
    recommended_project_levels = []
    collaborative_recommendations = []

    # Project-Based Learning Paths
    assoc_skills = {skill: row[skill] for skill in skill_columns_assoc}
    assoc_prefs = preferences[preferences["associate_id"] == associate_id]
    delivery_mode = assoc_prefs["preferred_format"].iloc[0] if not assoc_prefs.empty else None
    assoc_project_ids = [pid.strip() for pid in row["project_id"].split(",")]
    assoc_projects = projects[projects["project_id"].isin(assoc_project_ids)]

    if assoc_projects.empty:
        print(f"No projects found for associate {associate_id} with project_ids {assoc_project_ids}")
    else:
        max_required_levels = {}
        for skill in skill_columns_proj:
            levels = assoc_projects[skill]
            valid_levels = [skill_levels.get(level, 0) for level in levels if pd.notna(level) and level in skill_levels]
            if valid_levels:
                max_required_levels[skill] = {
                    "level": inverse_skill_levels[max(valid_levels)],
                    "level_int": max(valid_levels)
                }

        for req_skill, req_info in max_required_levels.items():
            req_level = req_info["level"]
            req_level_int = req_info["level_int"]
            current_level = assoc_skills.get(req_skill, None)
            if pd.isna(current_level):
                continue
            current_level_int = skill_levels.get(current_level, 0) if current_level in skill_levels else 0

            if current_level_int < req_level_int:
                course = recommend_course_tfidf(req_skill, req_level, delivery_mode)
                project_recommendations.append({"skill": req_skill, "course": course})
                project_skill_gaps.append({"skill": req_skill, "gap": f"L{current_level_int} → L{req_level_int}"})
                current_project_levels.append(f"{req_skill} - L{current_level_int}")
                recommended_project_levels.append(f"{req_skill} - L{req_level_int}")

    # Recommended Skills Training
    all_recommended = {}
    for col in ['skills_recommended_by_manager', 'skills_recommended_by_department', 'skills_selected_for_own']:
        rec_skills = parse_recommended_skills(row.get(col, ''))
        for skill, level in rec_skills.items():
            all_recommended[skill] = max(level, all_recommended.get(skill, 0))

    for skill, rec_level in sorted(all_recommended.items()):
        current_level = level_to_int(row.get(skill, 0))
        if rec_level > current_level:
            course = recommend_course_tfidf(skill, inverse_skill_levels[rec_level], delivery_mode)
            training_recommendations.append({"skill": skill, "course": course})
            training_skill_gaps.append(f"{skill} (L{current_level} → L{rec_level})")
            current_levels.append(f"{skill} - L{current_level}")
            recommended_levels.append(f"{skill} - L{rec_level}")

    # AI-Based Collaborative Training Recommendations
    peers = associates[associates["cluster"] == cluster]
    skill_gaps_collaborative = {}
    for skill in skill_columns_assoc:
        peer_levels = peers[skill].apply(level_to_int)
        centroid_level = int(kmeans.cluster_centers_[cluster][skill_columns_assoc.index(skill)])
        current_level = level_to_int(row.get(skill, 0))
        if centroid_level > current_level:
            gap = centroid_level - current_level
            skill_gaps_collaborative[skill] = {"gap": gap, "desired_level": inverse_skill_levels[centroid_level]}

    sorted_gaps = sorted(skill_gaps_collaborative.items(), key=lambda x: x[1]["gap"], reverse=True)[:3]
    for skill, info in sorted_gaps:
        course = recommend_course_tfidf(skill, info["desired_level"], delivery_mode)
        collaborative_recommendations.append(f"{skill}: {course}")

    # Format outputs
    project_skill_gaps_str = ", ".join(f"{gap['skill']} ({gap['gap']})" for gap in project_skill_gaps)
    trainings_by_project = ", ".join(f"{item['skill']}: {item['course']}" for item in project_recommendations)
    trainings_by_manager_dept_self = ", ".join(f"{item['skill']}: {item['course']}" for item in training_recommendations)
    collaborative_recommendations_str = ", ".join(collaborative_recommendations)

    return pd.Series({
        "project_recommendations": project_recommendations,
        "project_skill_gaps": project_skill_gaps_str if project_skill_gaps else "",
        "training_recommendations": training_recommendations,
        "skill_gaps_basedonrecommendation": ", ".join(training_skill_gaps),
        "current_skill_levels": ", ".join(current_levels),
        "recommended_skill_levels": ", ".join(recommended_levels),
        "current_skill_levels_forproject": ", ".join(current_project_levels) if current_project_levels else "",
        "recommended_skill_levels_forproject": ", ".join(recommended_project_levels) if recommended_project_levels else "",
        "trainings_recommended_by_project": trainings_by_project,
        "trainings_recommended_by_manager_department_self": trainings_by_manager_dept_self,
        "collaborative_training_recommendations": collaborative_recommendations_str
    })

# Apply the combined function
results = associates.apply(create_learning_path_and_trainings, axis=1)
associates = pd.concat([associates, results], axis=1)

# Define the desired column order
output_columns = [
    "associate_id",
    "role",
    "project_skill_gaps",
    "current_skill_levels_forproject",
    "recommended_skill_levels_forproject",
    "skill_gaps_basedonrecommendation",
    "current_skill_levels",
    "recommended_skill_levels",
    "trainings_recommended_by_project",
    "trainings_recommended_by_manager_department_self",
    "collaborative_training_recommendations"
]

# Save results
associates[output_columns].to_csv("combined_learning_pathways.csv", index=False)

print("✅ Combined project-based learning pathways, training assignments, and AI-based collaborative recommendations saved successfully!")
print(associates[output_columns].head(10))
# Out:
# TF-IDF matrix computed
# <ipython-input-4-a0687ff79452>:108: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   skill_matrix = associates[skill_columns_assoc].applymap(level_to_int).fillna(0)
# Associates clustered based on skill profiles
# External search failed for JUnit: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=JUnit%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01abd10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Spring Boot: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Spring%20Boot%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17fe50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Computer Vision: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Computer%20Vision%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a019bb10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Firewalls: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Firewalls%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a019b750>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Data Literacy: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Data%20Literacy%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17e5d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Networking: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Networking%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d49eb50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Tech Radar Creation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Tech%20Radar%20Creation%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a21d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Swift: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Swift%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a14d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for RxJS: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=RxJS%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01aaa10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Wireframing: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Wireframing%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17c390>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Blockchain Databases: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Blockchain%20Databases%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01991d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud AR/VR: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20AR/VR%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a4b90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Conflict Resolution: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Conflict%20Resolution%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17e1d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Performance Optimization: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Performance%20Optimization%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a019b990>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Spark: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Spark%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a2210>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for PyTorch: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=PyTorch%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f173f10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Future Thinking: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Future%20Thinking%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01aaf90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Blockchain: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Blockchain%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17fe50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Rust: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Rust%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a4ad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Mentoring: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Mentoring%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a0199fd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Spinnaker: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Spinnaker%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a2c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Technical Documentation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Technical%20Documentation%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17c710>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Motion Design: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Motion%20Design%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a00ca550>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for CI/CD Pipeline Design: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=CI/CD%20Pipeline%20Design%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a6dd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud Metaverse: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20Metaverse%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f170690>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Database Quantum Computing: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Database%20Quantum%20Computing%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17e950>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for ETL Processes: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=ETL%20Processes%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a5a90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Skills Gap Analysis: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Skills%20Gap%20Analysis%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a01a0450>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Communication: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Communication%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4eddd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Technical Documentation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Technical%20Documentation%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f46d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Mentoring: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Mentoring%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f6f90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Quantum Cloud Computing: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Quantum%20Cloud%20Computing%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f191950>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for TypeScript: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=TypeScript%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd0490>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Continuous Learning: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Continuous%20Learning%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99fbb0390>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Open Source Strategy: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Open%20Source%20Strategy%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4d3e50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for InnerSource Leadership: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=InnerSource%20Leadership%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f6eb310>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Database Security: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Database%20Security%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd0b50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Platform Engineering: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Platform%20Engineering%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f193f10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Data Pipelines: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Data%20Pipelines%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4d0950>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Adaptability: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Adaptability%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f1932d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Communication: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Communication%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd1850>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Test Data Management: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Test%20Data%20Management%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4d2f90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cross-Cultural UX: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cross-Cultural%20UX%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4c2fd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Problem Solving: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Problem%20Solving%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f6e9e10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Digital Transformation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Digital%20Transformation%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd08d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Agile Transformation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Agile%20Transformation%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f190c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for GitLab CI/CD: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=GitLab%20CI/CD%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4d1d90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Google Cloud: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Google%20Cloud%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17aad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Explainable AI: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Explainable%20AI%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd0890>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Remote Collaboration: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Remote%20Collaboration%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f190350>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Conflict Resolution: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Conflict%20Resolution%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4c2d50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Multi-Model Databases: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Multi-Model%20Databases%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f178ed0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud Carbon Footprint Reduction: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20Carbon%20Footprint%20Reduction%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4c1c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Docker: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Docker%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f190e10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Blue Teaming: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Blue%20Teaming%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4d26d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Digital Twin Architecture: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Digital%20Twin%20Architecture%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a0170c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud Metaverse: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20Metaverse%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd0610>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Digital Twin Architecture: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Digital%20Twin%20Architecture%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f192a90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for GitHub Actions: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=GitHub%20Actions%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4d1d10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Grafana: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Grafana%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a0171910>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for NewSQL: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=NewSQL%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4cb6d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for System Design: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=System%20Design%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4c3e50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Problem Solving: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Problem%20Solving%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efcb6d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Stakeholder Communication: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Stakeholder%20Communication%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99eff6810>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Continuous Learning: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Continuous%20Learning%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d509110>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Adobe XD: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Adobe%20XD%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f7090>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Chaos Testing: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Chaos%20Testing%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f4c10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Crisis Management: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Crisis%20Management%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f173fd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Budget Forecasting: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Budget%20Forecasting%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f1713d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud Governance: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20Governance%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f172d10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for AI Cloud Architecture: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=AI%20Cloud%20Architecture%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efb4dd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Design Systems: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Design%20Systems%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f6d50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Future Trends Analysis: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Future%20Trends%20Analysis%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efbe1d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Jest: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Jest%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f5710>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Creativity: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Creativity%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f5250>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for SIEM: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=SIEM%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efbc550>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cypress: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cypress%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4dd7d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Multi-Model Databases: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Multi-Model%20Databases%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efd5a10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Microservices Architecture: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Microservices%20Architecture%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f171e90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Spark: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Spark%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f7750>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Security Automation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Security%20Automation%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17f910>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Infrastructure as Code: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Infrastructure%20as%20Code%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efbffd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for SOC 2: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=SOC%202%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f18d650>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Design Systems: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Design%20Systems%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4dedd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Merger & Acquisition Integration: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Merger%20&%20Acquisition%20Integration%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efbfad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Performance Engineering: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Performance%20Engineering%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f6450>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Sustainability Architecture: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Sustainability%20Architecture%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d507ad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for UX for Blockchain: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=UX%20for%20Blockchain%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99fd69110>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Agile Methodologies: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Agile%20Methodologies%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d5297d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Pair Programming: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Pair%20Programming%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d527f10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Digital Literacy: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Digital%20Literacy%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d52c810>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Quantum Cryptography: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Quantum%20Cryptography%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f062fd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud Robotics: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20Robotics%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4de650>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Firewalls: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Firewalls%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f4350>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for MLOps: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=MLOps%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efb7ad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Blockchain Security: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Blockchain%20Security%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f171c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for PACT: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=PACT%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f4d10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for MITRE ATT&CK: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=MITRE%20ATT&CK%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f061850>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Allure Reports: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Allure%20Reports%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a0199d10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Problem Solving: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Problem%20Solving%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4de650>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Digital Transformation: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Digital%20Transformation%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f6c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for GraphQL: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=GraphQL%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f062a90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Time Management: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Time%20Management%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f170690>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Database DevOps: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Database%20DevOps%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17e550>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Creativity: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Creativity%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f71d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for NewSQL: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=NewSQL%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f062550>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Remote Collaboration: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Remote%20Collaboration%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a0199110>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cloud AR/VR: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cloud%20AR/VR%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4dcb50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Test Observability: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Test%20Observability%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4df710>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cryptography: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cryptography%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99efb4150>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Confluence: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Confluence%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f063150>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Critical Thinking: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Critical%20Thinking%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e9a0198490>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for JavaScript: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=JavaScript%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99f17d590>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Spark: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Spark%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99d4f5110>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# ...
# External search failed for Three.js: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Three.js%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99def4950>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Gatling: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Gatling%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99e13b4d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Google Cloud: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Google%20Cloud%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99df56310>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Big Data: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Big%20Data%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99de54cd0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Technical Evangelism: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Technical%20Evangelism%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99def7e90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Critical Thinking: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Critical%20Thinking%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dfe5650>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for JavaScript: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=JavaScript%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99de57390>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Future Thinking: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Future%20Thinking%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dfaeb90>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for AI Ethics: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=AI%20Ethics%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99deb2710>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Blockchain: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Blockchain%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dd89ed0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Agile Coaching: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Agile%20Coaching%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99deb38d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Spinnaker: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Spinnaker%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dd8b050>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Cucumber: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Cucumber%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dfe7c50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for GDPR Compliance: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=GDPR%20Compliance%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99e13ae10>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Java: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Java%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99e089410>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Metaverse Design: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Metaverse%20Design%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dfe6390>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Digital Twin Architecture: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Digital%20Twin%20Architecture%20L4%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99e1a9d50>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Reinforcement Learning: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Reinforcement%20Learning%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99def76d0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Test Observability: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Test%20Observability%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dd78ad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Vector Databases: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Vector%20Databases%20L2%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99df57ad0>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Time Management: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Time%20Management%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dd4c750>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Critical Thinking: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Critical%20Thinking%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99dd4e250>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# External search failed for Continuous Learning: HTTPSConnectionPool(host='api.classcentral.com', port=443): Max retries exceeded with url: /search?q=Continuous%20Learning%20L3%20course%20site:coursera.org%20OR%20site:edx.org%20OR%20site:udemy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x78e99de9a090>: Failed to resolve 'api.classcentral.com' ([Errno -2] Name or service not known)"))
# ✅ Combined project-based learning pathways, training assignments, and AI-based collaborative recommendations saved successfully!
#    associate_id                    role  \
# 0             1      Software Architect
# 1             2      Software Developer
# 2             3         Software Tester
# 3             4         Software Tester
# 4             5               Tech Lead
# 5             6         Project Manager
# 6             7  Database Administrator
# 7             8      Software Developer
# 8             9          Data Scientist
# 9            10      Software Developer
#
#                                   project_skill_gaps  \
# 0  Open Source Strategy (L1 → L2), Cloud Security...
# 1  Chaos Testing (L1 → L3), Playwright (L1 → L2),...
# 2  Quantum Cryptography (L2 → L4), JUnit (L2 → L4...
# 3  Electron (L1 → L3), Karate (L2 → L3), Continuo...
# 4  Engineering Metrics (L3 → L4), Change Data Cap...
# 5  Augmented Reality Interfaces (L1 → L3), Strang...
# 6  JUnit (L2 → L4), Electron (L1 → L3), Change Da...
# 7  JUnit (L1 → L4), Electron (L2 → L4), Change Da...
# 8  Quantum Cryptography (L1 → L2), Cloud Robotics...
# 9  JUnit (L2 → L3), Spring Boot (L3 → L4), Comput...
#
#                      current_skill_levels_forproject  \
# 0  Open Source Strategy - L1, Cloud Security - L2...
# 1  Chaos Testing - L1, Playwright - L1, AI Testin...
# 2  Quantum Cryptography - L2, JUnit - L2, Karate ...
# 3  Electron - L1, Karate - L2, Continuous Learnin...
# 4  Engineering Metrics - L3, Change Data Capture ...
# 5  Augmented Reality Interfaces - L1, Strangler P...
# 6  JUnit - L2, Electron - L1, Change Data Capture...
# 7  JUnit - L1, Electron - L2, Change Data Capture...
# 8  Quantum Cryptography - L1, Cloud Robotics - L1...
# 9  JUnit - L2, Spring Boot - L3, Computer Vision ...
#
#                  recommended_skill_levels_forproject  \
# 0  Open Source Strategy - L2, Cloud Security - L4...
# 1  Chaos Testing - L3, Playwright - L2, AI Testin...
# 2  Quantum Cryptography - L4, JUnit - L4, Karate ...
# 3  Electron - L3, Karate - L3, Continuous Learnin...
# 4  Engineering Metrics - L4, Change Data Capture ...
# 5  Augmented Reality Interfaces - L3, Strangler P...
# 6  JUnit - L4, Electron - L3, Change Data Capture...
# 7  JUnit - L4, Electron - L4, Change Data Capture...
# 8  Quantum Cryptography - L2, Cloud Robotics - L2...
# 9  JUnit - L3, Spring Boot - L4, Computer Vision ...
#
#                     skill_gaps_basedonrecommendation  \
# 0  AWS (L0 → L3), Cloud Blockchain (L0 → L4), Kot...
# 1  Azure (L0 → L2), Change Management (L0 → L3), ...
# 2  AWS (L0 → L3), Augmented Reality Interfaces (L...
# 3  Blockchain Security (L0 → L2), Cloud Digital T...
# 4  AI Security (L0 → L4), NewSQL (L0 → L2), NoSQL...
# 5  Backup & Recovery (L0 → L4), Columnar Database...
# 6  Angular (L0 → L2), Cypress (L0 → L4), Emotiona...
# 7  AI Cloud Architecture (L0 → L3), Change Data C...
# 8  Motion Design (L1 → L4), Performance Optimizat...
# 9  CI/CD Pipeline Design (L0 → L2), Cloud Metaver...
#
#                                 current_skill_levels  \
# 0  AWS - L0, Cloud Blockchain - L0, Kotlin - L0, ...
# 1  Azure - L0, Change Management - L0, Cloud Migr...
# 2  AWS - L0, Augmented Reality Interfaces - L0, F...
# 3  Blockchain Security - L0, Cloud Digital Twins ...
# 4  AI Security - L0, NewSQL - L0, NoSQL - L0, Zer...
# 5  Backup & Recovery - L0, Columnar Databases - L...
# 6  Angular - L0, Cypress - L0, Emotional Design -...
# 7  AI Cloud Architecture - L0, Change Data Captur...
# 8  Motion Design - L1, Performance Optimization -...
# 9  CI/CD Pipeline Design - L0, Cloud Metaverse - ...
#
#                             recommended_skill_levels  \
# 0  AWS - L3, Cloud Blockchain - L4, Kotlin - L4, ...
# 1  Azure - L2, Change Management - L3, Cloud Migr...
# 2  AWS - L3, Augmented Reality Interfaces - L2, F...
# 3  Blockchain Security - L2, Cloud Digital Twins ...
# 4  AI Security - L4, NewSQL - L2, NoSQL - L3, Zer...
# 5  Backup & Recovery - L4, Columnar Databases - L...
# 6  Angular - L2, Cypress - L4, Emotional Design -...
# 7  AI Cloud Architecture - L3, Change Data Captur...
# 8  Motion Design - L4, Performance Optimization -...
# 9  CI/CD Pipeline Design - L2, Cloud Metaverse - ...
#
#                     trainings_recommended_by_project  \
# 0  Open Source Strategy: Platform Engineering Str...
# 1  Chaos Testing: Mutation Testing Strategies, Pl...
# 2  Quantum Cryptography: Stakeholder Communicatio...
# 3  Electron: Terraform Multi-Cloud, Karate: Terra...
# 4  Engineering Metrics: Chaos Engineering Practic...
# 5  Augmented Reality Interfaces: Practical Worksh...
# 6  JUnit: Stakeholder Communication, Electron: El...
# 7  JUnit: Stakeholder Communication, Electron: St...
# 8  Quantum Cryptography: Quantum Database Concept...
# 9  JUnit: JUnit L3 Course (via External Search), ...
#
#     trainings_recommended_by_manager_department_self  \
# 0  AWS: AWS Solutions Architect, Cloud Blockchain...
# 1  Azure: API Gateway Configuration, Change Manag...
# 2  AWS: AWS Solutions Architect, Augmented Realit...
# 3  Blockchain Security: Blockchain Security, Clou...
# 4  AI Security: AI Security Threats, NewSQL: Vect...
# 5  Backup & Recovery: AI Security Threats, Column...
# 6  Angular: Linux Administration Essentials, Cypr...
# 7  AI Cloud Architecture: System Architecture Pla...
# 8  Motion Design: Metaverse Design Principles, Pe...
# 9  CI/CD Pipeline Design: CI/CD Pipeline Design L...
#
#               collaborative_training_recommendations
# 0  Git: Git Version Control Mastery, Communicatio...
# 1  Git: Git Version Control Mastery, Stakeholder ...
# 2  Pair Programming: Pair Programming Workshop, C...
# 3  Digital Literacy: Terraform Multi-Cloud, Selen...
# 4  Problem Solving: Terraform Multi-Cloud, Code R...
# 5  System Design: Jenkins Pipeline Design, Cloud ...
# 6  System Design: Blockchain System Design, Micro...
# 7  Git: Git Version Control Mastery, Technical Do...
# 8  Problem Solving: Terraform Multi-Cloud, Code R...
# 9  Communication: Communication L3 Course (via Ex...
